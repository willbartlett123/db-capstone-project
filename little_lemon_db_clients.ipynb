# %% [markdown]
# # Database Engineering Capstone
# ## Database Client Assignment

# %%
# import mysql connector
import mysql.connector as connector

# %%
# create connection
connection = connector.connect(
    host="localhost",
    user="admin1",
    password="willbart99",
    db = "LittleLemonDB"
)
print(connection)
# Out:
# <mysql.connector.connection_cext.CMySQLConnection object at 0x1061da900>

# %%
# show tables
cursor = connection.cursor()

show_tables_query = "SHOW tables" 
cursor.execute(show_tables_query)
results = cursor.fetchall()
for res in results:
    print(res)
# Out:
# ('Bookings',)
# ('Customers',)
# ('Menu',)
# ('OrderDeliveryStatus',)
# ('Orders',)
# ('ordersview',)
# ('Staff',)

# %%
# Query with JOIN
join_query = """
SELECT c.FirstName, c.LastName,
       c.PhoneNumber, c.Email,
       o.TotalCost
FROM Customers AS c
JOIN Orders AS o ON c.CustomerID = o.CustomerID
WHERE o.TotalCost > 60
"""

cursor.execute(join_query)
results = cursor.fetchall()
for res in results:
    print(res) # no sample data given, so no output to show
